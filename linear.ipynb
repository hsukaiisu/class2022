# %% [markdown]
# <a href="https://colab.research.google.com/github/bluecityisu/class2022/blob/main/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)
fig = plt.figure() #定義一個圖像窗口
plt.plot(xs, ys)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
  Dense(3,input_shape=[1]),
  Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
print(model.summary())

# %%
model.fit(xs, ys, epochs=100)

# %%
print(model.predict([8]))

# %%
model.get_layer('dense').get_weights()

# %%
model.get_layer('dense_1').get_weights()

# %%
# !pip install tensorflowjs
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(model, 'models')
